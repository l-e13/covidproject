# %%
from google.colab import files
import pandas as pd

# Upload file
uploaded = files.upload()

# Get the file name (first key in the uploaded dictionary)
file_name = list(uploaded.keys())[0]

# Load the CSV file
df = pd.read_csv(file_name, encoding='ISO-8859-1')

# Display first few rows
df.head()
# Out:
#      <input type="file" id="files-9a82399b-e0e3-4b79-a0f0-6a076d6efd2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a82399b-e0e3-4b79-a0f0-6a076d6efd2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df["Location"].value_counts())  # Check location counts after cleaning
# Out:
# Location
# New York, NY             395
# Washington, DC           373
# Los Angeles, CA          281
# Chicago, IL              155
# California, USA          153
#                         ...
# North Georgia              1
# Illinois, Chicago          1
# Austin TX                  1
# New Windsor, New York      1
# OHIO                       1
# Name: count, Length: 1674, dtype: int64

# %%
# Standardizing Location Names

# 📌 Step 1: Create a Mapping Dictionary to Standardize Locations
location_mapping = {
    "New York, NY": "New York",
    "New York, USA": "New York",
    "NYC": "New York",
    "Philadelphia, PA": "Pennsylvania",
    "Pennsylvania, USA": "Pennsylvania",
    "Los Angeles, CA": "California",
    "LA": "California",
    "San Francisco, CA": "California",
    "SF": "California",
    "Chicago, IL": "Illinois",
    "Houston, TX": "Texas",
    "Dallas, TX": "Texas",
    "Washington, D.C.": "D.C.",
    "Washington, DC": "D.C."
}

# 📌 Step 2: Apply Mapping to Standardize Locations
df["Location"] = df["Location"].replace(location_mapping)

# 📌 Step 3: Handle Missing or Unclear Locations
# Convert empty or unknown locations to "Unknown"
df["Location"] = df["Location"].fillna("Unknown")

# If needed, remove tweets with unknown locations:
df = df[df["Location"] != "Unknown"]

# 📌 Step 4: Verify Changes
df.head()
#print(df["Location"].value_counts())  # Check location counts after cleaning
# Out:
#    UserName  ScreenName        Location     TweetAt  \
# 0      3812       48764        Illinois  2020-03-16
# 1      3814       48766  Houston, Texas  2020-03-16
# 2      3818       48770      Denver, CO  2020-03-16
# 3      3825       48777  Ketchum, Idaho  2020-03-16
# 4      3827       48779        New York  2020-03-16
#
#                                        OriginalTweet Sentiment
# 0  Me: I don't need to stock up on food, I'll jus...  Positive
# 1  Lines at the grocery store have been unpredict...  Positive
# 2  For those who aren't struggling, please consid...  Positive
# 3  In preparation for higher demand and a potenti...  Negative
# 4  Do you see malicious price increases in NYC? T...  Negative

# %%
print(df["Location"].value_counts())  # Check location counts after cleaning
# Out:
# Location
# New York                 661
# California               487
# D.C.                     453
# Texas                    212
# Illinois                 173
#                         ...
# North Georgia              1
# Illinois, Chicago          1
# Austin TX                  1
# New Windsor, New York      1
# OHIO                       1
# Name: count, Length: 1664, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Ensure VADER is available
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

# Compute VADER sentiment scores for each tweet
df["VADER Score"] = df["OriginalTweet"].apply(lambda tweet: sia.polarity_scores(str(tweet))["compound"])

# Save the updated dataset with sentiment scores
df.to_csv("df_us_with_sentiment.csv", index=False)
files.download("df_us_with_sentiment.csv")  # Download file

# Display the first few rows of the new dataset
print(df.head())
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#    UserName  ScreenName        Location     TweetAt  \
# 0      3812       48764        Illinois  2020-03-16
# 1      3814       48766  Houston, Texas  2020-03-16
# 2      3818       48770      Denver, CO  2020-03-16
# 3      3825       48777  Ketchum, Idaho  2020-03-16
# 4      3827       48779        New York  2020-03-16
#
#                                        OriginalTweet Sentiment  VADER Score
# 0  Me: I don't need to stock up on food, I'll jus...  Positive       0.3400
# 1  Lines at the grocery store have been unpredict...  Positive       0.1901
# 2  For those who aren't struggling, please consid...  Positive       0.2892
# 3  In preparation for higher demand and a potenti...  Negative      -0.5423
# 4  Do you see malicious price increases in NYC? T...  Negative      -0.5267

# %%
from google.colab import files

df_us.to_csv("df_us.csv", index=False)  # Save file
files.download("df_us.csv")  # Download file
