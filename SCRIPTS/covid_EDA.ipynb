# %% [markdown]
# <a href="https://colab.research.google.com/github/l-e13/covidproject/blob/main/covid_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
file_path='/content/drive/MyDrive/DS_Final_Project/Corona_NLP_train.csv'

# Read the CSV file using pandas
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Show the first few rows
print(df.head())
# Out:
# Mounted at /content/drive
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
# 3      3802       48754        NaN  16-03-2020
# 4      3803       48755        NaN  16-03-2020
#
#                                        OriginalTweet           Sentiment
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1  advice Talk to your neighbours family to excha...            Positive
# 2  Coronavirus Australia: Woolworths to give elde...            Positive
# 3  My food stock is not the only one which is emp...            Positive
# 4  Me, ready to go at supermarket during the #COV...  Extremely Negative

# %%
df.shape
# Out:
# (41157, 6)

# %%
print(df.tail())
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# 41152  Airline pilots offering to stock supermarket s...             Neutral
# 41153  Response to complaint not provided citing COVI...  Extremely Negative
# 41154  You know itÂs getting tough when @KameronWild...            Positive
# 41155  Is it wrong that the smell of hand sanitizer i...             Neutral
# 41156  @TartiiCat Well new/used Rift S are going for ...            Negative

# %%
print(df.columns)
# Out:
# Index(['UserName', 'ScreenName', 'Location', 'TweetAt', 'OriginalTweet',
#        'Sentiment'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# UserName          int64
# ScreenName        int64
# Location         object
# TweetAt          object
# OriginalTweet    object
# Sentiment        object
# dtype: object

# %%
# convert tweetat to datetime format
df['TweetAt'] = pd.to_datetime(df['TweetAt'], format='%d-%m-%Y')
print(df['TweetAt'].head())
# Out:
# 0   2020-03-16
# 1   2020-03-16
# 2   2020-03-16
# 3   2020-03-16
# 4   2020-03-16
# Name: TweetAt, dtype: datetime64[ns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# EDA figure 2

sentiment_order = ["Extremely Negative", "Negative", "Neutral", "Positive", "Extremely Positive"]
avg_length = avg_length.reindex(sentiment_order)
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_length.index, y=avg_length.values, palette="mako", order=sentiment_order)

plt.title("Average Tweet Length (Words) Across Sentiment Categories")
plt.xlabel("Sentiment Category")
plt.ylabel("Average Tweet Length (Words)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# <ipython-input-8-98576e5ee227>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_length.index, y=avg_length.values, palette="mako", order=sentiment_order)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


print(df['Sentiment'].value_counts())

# Box plot of number of tweets in each sentiment category
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sentiment', y='TweetAt', data=df)

# Set plot title and labels
plt.title('Box Plot of Number of Tweets in Each Sentiment Category')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')

# Show the plot with rotated x-axis labels for better readability
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Sentiment
# Positive              11422
# Negative               9917
# Neutral                7713
# Extremely Positive     6624
# Extremely Negative     5481
# Name: count, dtype: int64
